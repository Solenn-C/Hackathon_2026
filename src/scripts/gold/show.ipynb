# %%
import pandas as pd
import os
import numpy as np

GOLD_DIR = "../../../data/gold"

for file in os.listdir(GOLD_DIR):
    if not file.endswith(".parquet"):
        continue
    print(file)
    df = pd.read_parquet(os.path.join(GOLD_DIR, file))
    display(df.head())
# Out:
# incendies.parquet
#    annee  numero departement code_insee           commune         date_alerte  \
# 0   1973       8          06      06060           Falicon 1973-01-09 13:50:00
# 1   1973    1871          83      83038     Châteaudouble 1973-01-28 13:25:00
# 2   1973    1872          83      83078  Moissac-Bellevue 1973-01-29 11:15:00
# 3   1973    1639          34      34163        Montarnaud 1973-01-29 13:00:00
# 4   1973       9          06      06012        Beausoleil 1973-01-29 15:00:00
#
#    surface_totale_m2  surface_foret_m2  surface_maquis_m2  \
# 0              10000            4700.0             4800.0
# 1              30000           14100.0            14400.0
# 2               6000            2820.0             2880.0
# 3             100000           47000.0            48000.0
# 4              40000           18800.0            19200.0
#
#    surface_autres_naturelles_m2  ...  surface_non_boisee_artificielle_m2  \
# ...

# %%
j1 = pd.read_parquet(os.path.join(d
